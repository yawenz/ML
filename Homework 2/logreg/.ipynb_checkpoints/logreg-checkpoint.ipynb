# %%
run logreg.py
# Out:
# Read in 1064 train and 133 test
# Update 1	TP -870.669342	HP -105.924944	TA 0.492481	HA 0.548872
# Update 6	TP -1022.850760	HP -139.208655	TA 0.509398	HA 0.436090
# Update 11	TP -718.970245	HP -101.616265	TA 0.561090	HA 0.548872
# Update 16	TP -1757.808273	HP -199.091671	TA 0.516917	HA 0.548872
# Update 21	TP -1695.680346	HP -199.641858	TA 0.537594	HA 0.563910
# Update 26	TP -860.626305	HP -107.626459	TA 0.617481	HA 0.661654
# Update 31	TP -962.248284	HP -119.988267	TA 0.603383	HA 0.631579
# Update 36	TP -1046.789018	HP -157.367169	TA 0.619361	HA 0.571429
# Update 41	TP -705.879920	HP -104.824786	TA 0.698308	HA 0.639098
# Update 46	TP -812.217302	HP -125.025714	TA 0.666353	HA 0.609023
# Update 51	TP -632.792394	HP -77.589767	TA 0.711466	HA 0.699248
# Update 56	TP -690.202205	HP -82.043830	TA 0.687970	HA 0.661654
# Update 61	TP -598.515595	HP -74.464778	TA 0.719925	HA 0.699248
# Update 66	TP -633.510998	HP -76.805725	TA 0.713346	HA 0.684211
# ...

# %%
lr.w
# Out:
# array([ 0.23153325,  0.17506209,  0.24314572, ..., -0.00277275,
#        -0.00787235,  0.00690002])
